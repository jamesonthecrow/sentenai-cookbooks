# %%
import numpy
import pandas
import matplotlib.pyplot as pyplot
import json
import arrow
import pytz

from sentenai import *

# %matplotlib inline

# %%
_API_KEY = 'YOUR_API_KEY_HERE'

# %%
# Create a client
sentenai = Sentenai(auth_key=_API_KEY)

# %% [markdown]
# # Load Data
# Data from the MBTA visualization
#
# http://mbtaviz.github.io/#trains
#
# https://github.com/mbtaviz/mbtaviz.github.io/tree/master/data

# %%
with open('../mbtaviz.github.io/data/marey-trips.json', 'r') as file:
    raw_data = json.load(file)
print raw_data[0]
# Out:
# {u'begin': 1391422380, u'line': u'blue', u'end': 1391423647, u'trip': u'B98A375E5', u'stops': [{u'stop': u'place-wondl', u'time': 1391422380}, {u'stop': u'place-rbmnl', u'time': 1391422433}, {u'stop': u'place-bmmnl', u'time': 1391422578}, {u'stop': u'place-sdmnl', u'time': 1391422686}, {u'stop': u'place-orhte', u'time': 1391422806}, {u'stop': u'place-wimnl', u'time': 1391422951}, {u'stop': u'place-aport', u'time': 1391423059}, {u'stop': u'place-mvbcl', u'time': 1391423221}, {u'stop': u'place-aqucl', u'time': 1391423392}, {u'stop': u'place-state', u'time': 1391423467}, {u'stop': u'place-gover', u'time': 1391423555}, {u'stop': u'place-bomnl', u'time': 1391423647}]}

# %%
# Each trip is defined via a nested json object with timestamps
# for stops made. Transform this into an event for each stop
events = []
for trip in raw_data:
    for stop in trip['stops']:
        event = {
            'line': trip['line'],
            'stop': stop['stop'],
            'trip': trip['trip'],
            'time': stop['time']
        }
        events.append(event)

# %%
stations = set()
for event in events:
    if event['line'] == 'red':
        stations.add(event['stop'])
print stations
# Out:
# set([u'place-chmnl', u'place-brdwy', u'place-asmnl', u'place-andrw', u'place-davis', u'place-cntsq', u'place-jfk', u'place-qnctr', u'place-dwnxg', u'place-smmnl', u'place-sstat', u'place-wlsta', u'place-brntn', u'place-portr', u'place-pktrm', u'place-alfcl', u'place-nqncy', u'place-qamnl', u'place-fldcr', u'place-shmnl', u'place-harsq', u'place-knncl'])

# %% [markdown]
# # Do this in pure pandas

# %%
df = pandas.DataFrame(events)
df['timestamp'] = df.time.apply(arrow.get)
df.head()
# Out:
#    line         stop        time       trip                  timestamp
# 0  blue  place-wondl  1391422380  B98A375E5  2014-02-03T10:13:00+00:00
# 1  blue  place-rbmnl  1391422433  B98A375E5  2014-02-03T10:13:53+00:00
# 2  blue  place-bmmnl  1391422578  B98A375E5  2014-02-03T10:16:18+00:00
# 3  blue  place-sdmnl  1391422686  B98A375E5  2014-02-03T10:18:06+00:00
# 4  blue  place-orhte  1391422806  B98A375E5  2014-02-03T10:20:06+00:00

# %%
df = df.sort_values(['line', 'trip', 'time'])
df.head()
# Out:
#     line         stop        time       trip                  timestamp
# 12  blue  place-orhte  1391422380  B98A375BB  2014-02-03T10:13:00+00:00
# 13  blue  place-wimnl  1391422560  B98A375BB  2014-02-03T10:16:00+00:00
# 14  blue  place-aport  1391422651  B98A375BB  2014-02-03T10:17:31+00:00
# 15  blue  place-mvbcl  1391422792  B98A375BB  2014-02-03T10:19:52+00:00
# 16  blue  place-aqucl  1391422926  B98A375BB  2014-02-03T10:22:06+00:00

# %%
df['timediff'] = df.groupby('trip')['time'].diff()
df['prev_stop'] = df.groupby('trip')['stop'].shift()
df.head()
# Out:
#     line         stop        time       trip                  timestamp  \
# 12  blue  place-orhte  1391422380  B98A375BB  2014-02-03T10:13:00+00:00
# 13  blue  place-wimnl  1391422560  B98A375BB  2014-02-03T10:16:00+00:00
# 14  blue  place-aport  1391422651  B98A375BB  2014-02-03T10:17:31+00:00
# 15  blue  place-mvbcl  1391422792  B98A375BB  2014-02-03T10:19:52+00:00
# 16  blue  place-aqucl  1391422926  B98A375BB  2014-02-03T10:22:06+00:00
#
#     timediff    prev_stop
# 12       NaN          NaN
# 13     180.0  place-orhte
# 14      91.0  place-wimnl
# 15     141.0  place-aport
# 16     134.0  place-mvbcl

# %%
df[(df.timediff > 5 * 60.) & (df.stop == 'place-harsq') & (df.prev_stop == 'place-portr')]
# Out:
#       line         stop        time       trip                  timestamp  \
# 15538  red  place-harsq  1391471870  R98338237  2014-02-03T23:57:50+00:00
# 15576  red  place-harsq  1391472409  R98338251  2014-02-04T00:06:49+00:00
# 14973  red  place-harsq  1391466980  R9833827D  2014-02-03T22:36:20+00:00
# 15696  red  place-harsq  1391473748  R98338307  2014-02-04T00:29:08+00:00
# 15043  red  place-harsq  1391467130  R98338349  2014-02-03T22:38:50+00:00
# 15558  red  place-harsq  1391472032  R983383CE  2014-02-04T00:00:32+00:00
#
#        timediff    prev_stop
# 15538     333.0  place-portr
# 15576     507.0  place-portr
# 14973     593.0  place-portr
# 15696     309.0  place-portr
# 15043     436.0  place-portr
# 15558     369.0  place-portr

# %% [markdown]
# # Create a stream and insert events

# %%
# Check what streams I have so far
sentenai.streams()
# Out:
# <type 'list'>
# [Stream(name="mbta-blue"),
#  Stream(name="weather-daily-boston"),
#  Stream(name="test-stream"),
#  Stream(name="mbta-orange"),
#  Stream(name="mbta-vis"),
#  Stream(name="mbta-red")]

# %%
mbta_stream = stream('mbta-vis')

# %%
# Make a single stream
mbta_stream = stream('mbta-vis')

for idx, event in enumerate(events):
    if idx % 500 == 0:
        print '%d of %d' % (idx, len(events))
    event_id = sentenai.put(mbta_stream, event, timestamp=arrow.get(event['time']))

# %%
# Make a stream for each line
for idx, event in enumerate(events):
    if idx % 500 == 0:
        print '%d of %d' % (idx, len(events))
    mbta_stream = stream('mbta-%s' % event['line'])
    event_id = sentenai.put(mbta_stream, event, timestamp=arrow.get(event['time']))
# Out:
# 0 of 17718
# 500 of 17718
# 1000 of 17718
# 1500 of 17718
# 2000 of 17718
# 2500 of 17718
# 3000 of 17718
# 3500 of 17718
# 4000 of 17718
# 4500 of 17718
# 5000 of 17718
# 5500 of 17718
# 6000 of 17718
# 6500 of 17718
# 7000 of 17718
# 7500 of 17718
# 8000 of 17718
# 8500 of 17718
# 9000 of 17718
# 9500 of 17718
# 10000 of 17718
# 10500 of 17718
# 11000 of 17718
# 11500 of 17718
# 12000 of 17718
# 12500 of 17718
# 13000 of 17718
# 13500 of 17718
# 14000 of 17718
# 14500 of 17718
# 15000 of 17718
# 15500 of 17718
# 16000 of 17718
# 16500 of 17718
# 17000 of 17718
# 17500 of 17718

# %%
# Create a stream per trip
trips = set()

# Lets limit this to only a few dozen trips
trip_limit = 500
for idx, evt in enumerate(events):
    if idx % 1000 == 0:
        print '%d of %d' % (idx, len(events))
    if evt['line'] != 'red':
        continue
    accept_trip = (
        (len(trips) <= trip_limit) or 
        (len(trips) > trip_limit and evt['trip'] in trips)
    )
    if accept_trip:
        trips.add(evt['trip'])
        mbta_stream = stream('mbta-%s' % evt['trip'])
        event_id = sentenai.put(
            mbta_stream, 
            evt, 
            timestamp=arrow.get(evt['time'])
        )
# Out:
# 0 of 17718
# 500 of 17718
# 1000 of 17718
# 1500 of 17718
# 2000 of 17718
# 2500 of 17718
# 3000 of 17718
# 3500 of 17718
# 4000 of 17718
# 4500 of 17718
# 5000 of 17718
# 5500 of 17718
# 6000 of 17718
# 6500 of 17718
# 7000 of 17718
# 7500 of 17718
# 8000 of 17718
# 8500 of 17718
# 9000 of 17718
# 9500 of 17718
# 10000 of 17718
# 10500 of 17718
# 11000 of 17718
# 11500 of 17718
# 12000 of 17718
# 12500 of 17718
# 13000 of 17718
# 13500 of 17718
# 14000 of 17718
# 14500 of 17718
# 15000 of 17718
# 15500 of 17718
# 16000 of 17718
# 16500 of 17718
# 17000 of 17718
# 17500 of 17718

# %% [markdown]
# # Journey to work.
# In this example lets assume I live near the Porter Square subway stop and commute to Downtown Crossing in Boston for work. I don't like getting stuck on the subway and would like to find out how often my commute is longer than 20 minutes.

# %%
# Query a single stream to get all events in a single trip.
s = stream('mbta-R98338292')

sentenai.query(select(), returning={s: True}).dataframe(s)
# Out:
# ---------------------------------------------------------------------------
# SentenaiException                         Traceback (most recent call last)
# <ipython-input-29-4620d7227c42> in <module>()
#       2 s = stream('mbta-R98338292')
#       3
# ----> 4 sentenai.query(select(), returning={s: True}).dataframe(s)
#
# /Users/jltoole/.pyenv/versions/2.7.10/envs/sentenai/lib/python2.7/site-packages/sentenai/api.pyc in query(self, query, returning, limit)
#     192                             }
#     193         """
# --> 194         return FlareCursor(self, query, returning, limit)()
#     195
#     196
#
# /Users/jltoole/.pyenv/versions/2.7.10/envs/sentenai/lib/python2.7/site-packages/sentenai/api.pyc in __call__(self)
#     407
#     408     def __call__(self):
# --> 409         return FlareResult(self._client, self._query, self._execute(self._query), self._returning)
#     410
#     411     def _execute(self, query):
#
# /Users/jltoole/.pyenv/versions/2.7.10/envs/sentenai/lib/python2.7/site-packages/sentenai/api.pyc in _execute(self, query)
#     462             raise FlareSyntaxError
#     463         elif resp.status_code >= 500:
# --> 464             raise SentenaiException("Something went wrong.")
#     465         elif resp.status_code != 200:
#     466             raise Exception(resp.status_code)
#
# SentenaiException: Something went wrong.

# %%
# Get all events in a trip if the trip is more than 20 minutes

s = stream('mbta-R983382C1')
query = select(
).span(s.stop == 'place-portr'
).then(s.stop == 'place-dwnxg', within=delta(minutes=20))
res = sentenai.query(
    query,
    returning={s: True}
).dataframe(s)
print query
res
# Out:
# ---------------------------------------------------------------------------
# SentenaiException                         Traceback (most recent call last)
# <ipython-input-28-f523e6b12b71> in <module>()
#       7 res = sentenai.query(
#       8     query,
# ----> 9     returning={s: True}
#      10 ).dataframe(s)
#      11 print query
#
# /Users/jltoole/.pyenv/versions/2.7.10/envs/sentenai/lib/python2.7/site-packages/sentenai/api.pyc in query(self, query, returning, limit)
#     192                             }
#     193         """
# --> 194         return FlareCursor(self, query, returning, limit)()
#     195
#     196
#
# /Users/jltoole/.pyenv/versions/2.7.10/envs/sentenai/lib/python2.7/site-packages/sentenai/api.pyc in __call__(self)
#     407
#     408     def __call__(self):
# --> 409         return FlareResult(self._client, self._query, self._execute(self._query), self._returning)
#     410
#     411     def _execute(self, query):
#
# /Users/jltoole/.pyenv/versions/2.7.10/envs/sentenai/lib/python2.7/site-packages/sentenai/api.pyc in _execute(self, query)
#     462             raise FlareSyntaxError
#     463         elif resp.status_code >= 500:
# --> 464             raise SentenaiException("Something went wrong.")
#     465         elif resp.status_code != 200:
#     466             raise Exception(resp.status_code)
#
# SentenaiException: Something went wrong.

# %%
s
# Out:
# Stream(name="mbta-R983382C1")

# %%
# Now lets apply this query to all trip streams to find our
# which ones have long commutes.

def find_long_commutes(strm, duration=20):
    return sentenai.query(
        select(
        ).span(
            strm.stop == 'place-portr'
        ).then(
            strm.stop == 'place-dwnxg', within=delta(minutes=duration)
        ))

# Query all streams based on meta data to find the streams
# corresponding to redline trips. A regular expression is
# used.
streams = sentenai.streams(name=r'mbta-R.+')
print 'RedLine streams found: %d' % len(streams)

# Apply the query to all streams.
results = map(lambda x: find_long_commutes(x), [s])
# Out:
# <type 'list'>
# RedLine streams found: 441
# ---------------------------------------------------------------------------
# SentenaiException                         Traceback (most recent call last)
# <ipython-input-24-7a6c52907036> in <module>()
#      18
#      19 # Apply the query to all streams.
# ---> 20 results = map(lambda x: find_long_commutes(x), [s])
#
# <ipython-input-24-7a6c52907036> in <lambda>(x)
#      18
#      19 # Apply the query to all streams.
# ---> 20 results = map(lambda x: find_long_commutes(x), [s])
#
# <ipython-input-24-7a6c52907036> in find_long_commutes(strm, duration)
#       8             strm.stop == 'place-portr'
#       9         ).then(
# ---> 10             strm.stop == 'place-dwnxg', within=delta(minutes=20)
#      11         ))
#      12
#
# /Users/jltoole/.pyenv/versions/2.7.10/envs/sentenai/lib/python2.7/site-packages/sentenai/api.pyc in query(self, query, returning, limit)
#     192                             }
#     193         """
# --> 194         return FlareCursor(self, query, returning, limit)()
#     195
#     196
#
# /Users/jltoole/.pyenv/versions/2.7.10/envs/sentenai/lib/python2.7/site-packages/sentenai/api.pyc in __call__(self)
#     407
#     408     def __call__(self):
# --> 409         return FlareResult(self._client, self._query, self._execute(self._query), self._returning)
#     410
#     411     def _execute(self, query):
#
# /Users/jltoole/.pyenv/versions/2.7.10/envs/sentenai/lib/python2.7/site-packages/sentenai/api.pyc in _execute(self, query)
#     462             raise FlareSyntaxError
#     463         elif resp.status_code >= 500:
# --> 464             raise SentenaiException("Something went wrong.")
#     465         elif resp.status_code != 200:
#     466             raise Exception(resp.status_code)
#
# SentenaiException: Something went wrong.

# %%
# We can also write the same query using switch statements.
# Here we define the beginning and end of a span by switches between
# event states, or stations in this case.
s = stream('mbta-R983382C1')
transition1 = event(V.stop == 'place-davis') >> event(V.stop == 'place-portr')# >> event(V.stop == 'place-harsq')
transition2 = event(V.stop == 'place-pktrm') >> event(V.stop == 'place-dwnxg') >> event(V.stop == 'place-sstat')
transition3 = event(V.stop == 'place-davis') >> event(V.stop == 'place-portr') >> event(V.stop == 'place-harsq')
query = select(
).span(s(transition1), min=delta(minutes=1)
)#.then(s(transition2), within=delta(minutes=100))
res = sentenai.query(
    query,
    returning={s: True}
).dataframe(s)
print query
res

# %%
s = stream('mbta-red')
query = select(
).span(s.stop == 'place-davis'
).then(s.stop == 'place-sstat', max=delta(days=1))
res = sentenai.query(
    query,
    returning={s: True}
).dataframe(s)
print query
res
# Out:
# select
#     s:stop == "place-davis";
#     s:stop == "place-sstat" within  for at most 1d
#                                                   line         stop  \
# .ts                       .stream  .span .delta
# 2014-02-03 10:46:29+00:00 mbta-red 0     00:00:00  red  place-davis
# 2014-02-03 10:47:06+00:00 mbta-red 0     00:00:37  red  place-sstat
# 2014-02-03 10:53:06+00:00 mbta-red 1     00:00:00  red  place-davis
# 2014-02-03 10:53:08+00:00 mbta-red 1     00:00:02  red  place-sstat
# 2014-02-03 10:55:19+00:00 mbta-red 2     00:00:00  red  place-davis
# 2014-02-03 10:55:29+00:00 mbta-red 2     00:00:10  red  place-sstat
# 2014-02-03 11:46:31+00:00 mbta-red 3     00:00:00  red  place-davis
# 2014-02-03 11:46:37+00:00 mbta-red 3     00:00:06  red  place-sstat
# 2014-02-03 12:05:04+00:00 mbta-red 4     00:00:00  red  place-davis
# 2014-02-03 12:05:15+00:00 mbta-red 4     00:00:11  red  place-sstat
# 2014-02-03 12:36:11+00:00 mbta-red 5     00:00:00  red  place-davis
# 2014-02-03 12:36:32+00:00 mbta-red 5     00:00:21  red  place-sstat
# 2014-02-03 13:15:29+00:00 mbta-red 6     00:00:00  red  place-davis
# 2014-02-03 13:15:30+00:00 mbta-red 6     00:00:01  red  place-sstat
# 2014-02-03 13:35:40+00:00 mbta-red 7     00:00:00  red  place-davis
# 2014-02-03 13:35:55+00:00 mbta-red 7     00:00:15  red  place-sstat
# 2014-02-03 13:50:37+00:00 mbta-red 8     00:00:00  red  place-davis
# 2014-02-03 13:50:42+00:00 mbta-red 8     00:00:05  red  place-sstat
# 2014-02-03 14:28:00+00:00 mbta-red 9     00:00:00  red  place-davis
# 2014-02-03 14:28:14+00:00 mbta-red 9     00:00:14  red  place-sstat
#                                          00:00:14  red  place-portr
# 2014-02-03 15:18:34+00:00 mbta-red 10    00:00:00  red  place-davis
# 2014-02-03 15:18:43+00:00 mbta-red 10    00:00:09  red  place-sstat
#                                          00:00:09  red  place-brdwy
# 2014-02-03 15:26:38+00:00 mbta-red 11    00:00:00  red  place-davis
# 2014-02-03 15:27:24+00:00 mbta-red 11    00:00:46  red  place-sstat
# 2014-02-03 15:31:47+00:00 mbta-red 12    00:00:00  red  place-davis
# 2014-02-03 15:32:25+00:00 mbta-red 12    00:00:38  red  place-sstat
# 2014-02-03 15:46:18+00:00 mbta-red 13    00:00:00  red  place-davis
# 2014-02-03 15:46:20+00:00 mbta-red 13    00:00:02  red  place-sstat
# ...                                                ...          ...
# 2014-02-03 16:45:29+00:00 mbta-red 16    00:00:11  red  place-sstat
# 2014-02-03 18:39:02+00:00 mbta-red 17    00:00:00  red  place-davis
# 2014-02-03 18:39:14+00:00 mbta-red 17    00:00:12  red  place-sstat
# 2014-02-03 19:58:08+00:00 mbta-red 18    00:00:00  red  place-davis
# 2014-02-03 19:58:25+00:00 mbta-red 18    00:00:17  red  place-sstat
# 2014-02-03 20:25:33+00:00 mbta-red 19    00:00:00  red  place-davis
# 2014-02-03 20:25:34+00:00 mbta-red 19    00:00:01  red  place-sstat
# 2014-02-03 20:57:52+00:00 mbta-red 20    00:00:00  red  place-davis
#                                          00:00:00  red  place-fldcr
# 2014-02-03 20:58:07+00:00 mbta-red 20    00:00:15  red  place-sstat
# 2014-02-04 00:28:40+00:00 mbta-red 21    00:00:00  red  place-davis
# 2014-02-04 00:28:51+00:00 mbta-red 21    00:00:11  red  place-sstat
# 2014-02-04 00:36:17+00:00 mbta-red 22    00:00:00  red  place-davis
# 2014-02-04 00:36:19+00:00 mbta-red 22    00:00:02  red  place-sstat
# 2014-02-04 02:00:35+00:00 mbta-red 23    00:00:00  red  place-davis
# 2014-02-04 02:00:36+00:00 mbta-red 23    00:00:01  red  place-sstat
# 2014-02-04 02:08:39+00:00 mbta-red 24    00:00:00  red  place-davis
# 2014-02-04 02:08:41+00:00 mbta-red 24    00:00:02  red  place-sstat
# 2014-02-04 02:16:37+00:00 mbta-red 25    00:00:00  red  place-davis
# 2014-02-04 02:16:50+00:00 mbta-red 25    00:00:13  red  place-sstat
# 2014-02-04 03:26:23+00:00 mbta-red 26    00:00:00  red  place-davis
# 2014-02-04 03:27:07+00:00 mbta-red 26    00:00:44  red  place-sstat
# 2014-02-04 04:10:01+00:00 mbta-red 27    00:00:00  red  place-davis
# 2014-02-04 04:10:03+00:00 mbta-red 27    00:00:02  red  place-sstat
# 2014-02-04 04:23:22+00:00 mbta-red 28    00:00:00  red  place-davis
# 2014-02-04 04:24:01+00:00 mbta-red 28    00:00:39  red  place-sstat
# 2014-02-04 04:28:34+00:00 mbta-red 29    00:00:00  red  place-davis
# 2014-02-04 04:28:48+00:00 mbta-red 29    00:00:14  red  place-sstat
# 2014-02-04 05:47:22+00:00 mbta-red 30    00:00:00  red  place-davis
# 2014-02-04 05:47:56+00:00 mbta-red 30    00:00:34  red  place-sstat
#
#                                                          time       trip
# .ts                       .stream  .span .delta
# 2014-02-03 10:46:29+00:00 mbta-red 0     00:00:00  1391424389  R9833829B
# 2014-02-03 10:47:06+00:00 mbta-red 0     00:00:37  1391424426  R983381D8
# 2014-02-03 10:53:06+00:00 mbta-red 1     00:00:00  1391424786  R983381D0
# 2014-02-03 10:53:08+00:00 mbta-red 1     00:00:02  1391424788  R983382D4
# 2014-02-03 10:55:19+00:00 mbta-red 2     00:00:00  1391424919  R983383B4
# 2014-02-03 10:55:29+00:00 mbta-red 2     00:00:10  1391424929  R98338200
# 2014-02-03 11:46:31+00:00 mbta-red 3     00:00:00  1391427991  R9833822D
# 2014-02-03 11:46:37+00:00 mbta-red 3     00:00:06  1391427997  R9833835F
# 2014-02-03 12:05:04+00:00 mbta-red 4     00:00:00  1391429104  R9833834B
# 2014-02-03 12:05:15+00:00 mbta-red 4     00:00:11  1391429115  R983382B6
# 2014-02-03 12:36:11+00:00 mbta-red 5     00:00:00  1391430971  R983381D2
# 2014-02-03 12:36:32+00:00 mbta-red 5     00:00:21  1391430992  R98338202
# 2014-02-03 13:15:29+00:00 mbta-red 6     00:00:00  1391433329  R983382CF
# 2014-02-03 13:15:30+00:00 mbta-red 6     00:00:01  1391433330  R983383A1
# 2014-02-03 13:35:40+00:00 mbta-red 7     00:00:00  1391434540  R983382FC
# 2014-02-03 13:35:55+00:00 mbta-red 7     00:00:15  1391434555  R9833829E
# 2014-02-03 13:50:37+00:00 mbta-red 8     00:00:00  1391435437  R9833832E
# 2014-02-03 13:50:42+00:00 mbta-red 8     00:00:05  1391435442  R98338361
# 2014-02-03 14:28:00+00:00 mbta-red 9     00:00:00  1391437680  R983381DC
# 2014-02-03 14:28:14+00:00 mbta-red 9     00:00:14  1391437694  R983383B7
#                                          00:00:14  1391437694  R98338381
# 2014-02-03 15:18:34+00:00 mbta-red 10    00:00:00  1391440714  R983382D8
# 2014-02-03 15:18:43+00:00 mbta-red 10    00:00:09  1391440723  R98338217
#                                          00:00:09  1391440723  R983382B2
# 2014-02-03 15:26:38+00:00 mbta-red 11    00:00:00  1391441198  R9833828D
# 2014-02-03 15:27:24+00:00 mbta-red 11    00:00:46  1391441244  R983382BA
# 2014-02-03 15:31:47+00:00 mbta-red 12    00:00:00  1391441507  R9833825A
# 2014-02-03 15:32:25+00:00 mbta-red 12    00:00:38  1391441545  R98338231
# 2014-02-03 15:46:18+00:00 mbta-red 13    00:00:00  1391442378  R983382BA
# 2014-02-03 15:46:20+00:00 mbta-red 13    00:00:02  1391442380  R9833834F
# ...                                                       ...        ...
# 2014-02-03 16:45:29+00:00 mbta-red 16    00:00:11  1391445929  R98338207
# 2014-02-03 18:39:02+00:00 mbta-red 17    00:00:00  1391452742  R9833838C
# 2014-02-03 18:39:14+00:00 mbta-red 17    00:00:12  1391452754  R983382BE
# 2014-02-03 19:58:08+00:00 mbta-red 18    00:00:00  1391457488  R9833833B
# 2014-02-03 19:58:25+00:00 mbta-red 18    00:00:17  1391457505  R9833820B
# 2014-02-03 20:25:33+00:00 mbta-red 19    00:00:00  1391459133  R98338372
# 2014-02-03 20:25:34+00:00 mbta-red 19    00:00:01  1391459134  R9833824D
# 2014-02-03 20:57:52+00:00 mbta-red 20    00:00:00  1391461072  R983382C1
#                                          00:00:00  1391461072  R98338260
# 2014-02-03 20:58:07+00:00 mbta-red 20    00:00:15  1391461087  R9833821E
# 2014-02-04 00:28:40+00:00 mbta-red 21    00:00:00  1391473720  R9833827F
# 2014-02-04 00:28:51+00:00 mbta-red 21    00:00:11  1391473731  R983382DE
# 2014-02-04 00:36:17+00:00 mbta-red 22    00:00:00  1391474177  R98338392
# 2014-02-04 00:36:19+00:00 mbta-red 22    00:00:02  1391474179  R98338271
# 2014-02-04 02:00:35+00:00 mbta-red 23    00:00:00  1391479235  R983381F8
# 2014-02-04 02:00:36+00:00 mbta-red 23    00:00:01  1391479236  R983382F5
# 2014-02-04 02:08:39+00:00 mbta-red 24    00:00:00  1391479719  R98338341
# 2014-02-04 02:08:41+00:00 mbta-red 24    00:00:02  1391479721  R98338378
# 2014-02-04 02:16:37+00:00 mbta-red 25    00:00:00  1391480197  R98338359
# 2014-02-04 02:16:50+00:00 mbta-red 25    00:00:13  1391480210  R983382C7
# 2014-02-04 03:26:23+00:00 mbta-red 26    00:00:00  1391484383  R983382F7
# 2014-02-04 03:27:07+00:00 mbta-red 26    00:00:44  1391484427  R98338313
# 2014-02-04 04:10:01+00:00 mbta-red 27    00:00:00  1391487001  R98338269
# 2014-02-04 04:10:03+00:00 mbta-red 27    00:00:02  1391487003  R98338396
# 2014-02-04 04:23:22+00:00 mbta-red 28    00:00:00  1391487802  R9833826A
# 2014-02-04 04:24:01+00:00 mbta-red 28    00:00:39  1391487841  R983383B0
# 2014-02-04 04:28:34+00:00 mbta-red 29    00:00:00  1391488114  R98338396
# 2014-02-04 04:28:48+00:00 mbta-red 29    00:00:14  1391488128  R98338344
# 2014-02-04 05:47:22+00:00 mbta-red 30    00:00:00  1391492842  R9833826B
# 2014-02-04 05:47:56+00:00 mbta-red 30    00:00:34  1391492876  R98338286
#
# [65 rows x 4 columns]

# %%
# Query all stream meta data to find only the streams
# corresponding to the red line trips.
streams = sentenai.streams(name=r'mbta-R.+')[:10] #sentenai.streams(name=r'mbta-[A-Z].+')
print len(streams), streams[:10]
# Out:
# <type 'list'>
# 10 [Stream(name="mbta-R9833839A"), Stream(name="mbta-R983382C1"), Stream(name="mbta-R9833839B"), Stream(name="mbta-R9833838A"), Stream(name="mbta-R983382FF"), Stream(name="mbta-R9833827E"), Stream(name="mbta-R9833839C"), Stream(name="mbta-R9833838D"), Stream(name="mbta-R983382A6"), Stream(name="mbta-R9833826B")]

# %%
def find_delays(strm):
    '''In this case `after` will key off of the state of the stream change.
    So the stream changes from porter to harvard starting the after clock at
    the end of the porter window not when the train first arrives at porter'''
    return sentenai.query(
        select(
        ).span(
            strm.stop == 'place-portr', min=delta(minutes=5)
        ).then(
            strm.stop == 'place-harsq'
        ))

results = map(lambda x: find_delays(x), streams)

# %%
dfs = pandas.concat([r.dataframe(s) for r, s in zip(results, streams)], axis=0)
dfs.head()
# Out:
#                                                         line         stop  \
# .ts                       .stream        .span .delta
# 2014-02-04 00:23:59+00:00 mbta-R98338307 0     00:00:00  red  place-portr
# 2014-02-04 00:29:08+00:00 mbta-R98338307 0     00:05:09  red  place-harsq
# 2014-02-03 23:52:17+00:00 mbta-R98338237 0     00:00:00  red  place-portr
# 2014-02-03 23:57:50+00:00 mbta-R98338237 0     00:05:33  red  place-harsq
# 2014-02-03 22:31:34+00:00 mbta-R98338349 0     00:00:00  red  place-portr
#
#                                                                time       trip
# .ts                       .stream        .span .delta
# 2014-02-04 00:23:59+00:00 mbta-R98338307 0     00:00:00  1391473439  R98338307
# 2014-02-04 00:29:08+00:00 mbta-R98338307 0     00:05:09  1391473748  R98338307
# 2014-02-03 23:52:17+00:00 mbta-R98338237 0     00:00:00  1391471537  R98338237
# 2014-02-03 23:57:50+00:00 mbta-R98338237 0     00:05:33  1391471870  R98338237
# 2014-02-03 22:31:34+00:00 mbta-R98338349 0     00:00:00  1391466694  R98338349

# %%
def find_long_commutes(strm):
    return sentenai.query(
        select(
        ).span(
            strm.stop == 'place-portr' # find a state change from davis which will be porter
        ).then(
            strm.stop == 'place-dwnxg', within=delta(minutes=20) # look for changes to DTX more than 20 minutes after not being davis anymore
        ))

results = map(lambda x: find_long_commutes(x), streams)

# %%
dfs = pandas.concat([r.dataframe(s) for r, s in zip(results, streams)], axis=0)
dfs.head()
# Out:
#                                                         line         stop  \
# .ts                       .stream        .span .delta
# 2014-02-03 20:59:53+00:00 mbta-R983382C1 0     00:00:00  red  place-portr
# 2014-02-03 21:02:45+00:00 mbta-R983382C1 0     00:02:52  red  place-harsq
# 2014-02-03 21:06:19+00:00 mbta-R983382C1 0     00:06:26  red  place-cntsq
# 2014-02-03 21:09:07+00:00 mbta-R983382C1 0     00:09:14  red  place-knncl
# 2014-02-03 21:13:34+00:00 mbta-R983382C1 0     00:13:41  red  place-chmnl
#
#                                                                time       trip
# .ts                       .stream        .span .delta
# 2014-02-03 20:59:53+00:00 mbta-R983382C1 0     00:00:00  1391461193  R983382C1
# 2014-02-03 21:02:45+00:00 mbta-R983382C1 0     00:02:52  1391461365  R983382C1
# 2014-02-03 21:06:19+00:00 mbta-R983382C1 0     00:06:26  1391461579  R983382C1
# 2014-02-03 21:09:07+00:00 mbta-R983382C1 0     00:09:14  1391461747  R983382C1
# 2014-02-03 21:13:34+00:00 mbta-R983382C1 0     00:13:41  1391462014  R983382C1

# %%
dfs.trip.unique().shape
# Out:
# (4,)

# %% [markdown]
# # What Won't Work

# %%
mbta_stream = stream('mbta-red')

# %%
# This doesn't work because it doesn't group things within
# the same trip
query = select(
).span(
    mbta_stream.stop == 'place-portr'
).then(
    mbta_stream.stop == 'place-harsq',
)

print query
# Out:
# select
#     mbta_stream:stop == "place-portr";
#     mbta_stream:stop == "place-harsq" within

# %%
# Lets try a switch statement
transition = event(V.stop == 'place-davis') >> event(V.stop == 'place-portr') >> event(V.stop == 'place-harsq')

query = select(
).span(
    mbta_stream(transition)
).then(
    mbta_stream.stop == 'place-cntsq', after=delta(minutes=2)
)
print query
# Out:
# select
#     mbta_stream:(stop == "place-davis" -> stop == "place-portr" -> stop == "place-harsq");
#     mbta_stream:stop == "place-cntsq" after 2m

# %%
#
query = select(
).span(
    mbta_stream.stop == 'place-portr'
).then(
    mbta_stream.stop == 'place-harsq', after=delta(minutes=2), within=delta(minutes=20)
)
print query
# Out:
# select
#     mbta_stream:stop == "place-portr";
#     mbta_stream:stop == "place-harsq" after 2m within 20m

# %%
mbta_stream = stream('mbta-red')
results = sentenai.query(query,
    returning = {mbta_stream: True}
)
print results.stats()
# Out:
# {}

# %%
query = select(
).span(
    (s1.stop == 'place-harsq') | (s2.stop == 'place-harsq')
).then(
    (s1.stop == 'place-cntsq') | (s2.stop == 'place-cntsq')
)

results = sentenai.query(
    query,
    returning={s1: True, s2: True}
)

# %%
df = results.dataframe()

# %%
pandas.concat(df.values())
# Out:
#                                                         line         stop  \
# .ts                       .stream        .span .delta
# 2014-02-03 10:23:06+00:00 mbta-R98338241 0     00:00:00  red  place-harsq
# 2014-02-03 10:27:09+00:00 mbta-R98338241 0     00:04:03  red  place-cntsq
# 2014-02-03 10:35:49+00:00 mbta-R98338241 1     00:00:00  red  place-dwnxg
# 2014-02-03 10:37:55+00:00 mbta-R98338241 1     00:02:06  red  place-sstat
# 2014-02-03 10:35:34+00:00 mbta-R98338254 1     00:00:00  red  place-harsq
# 2014-02-03 10:39:26+00:00 mbta-R98338254 1     00:03:52  red  place-cntsq
#
#                                                                time       trip
# .ts                       .stream        .span .delta
# 2014-02-03 10:23:06+00:00 mbta-R98338241 0     00:00:00  1391422986  R98338241
# 2014-02-03 10:27:09+00:00 mbta-R98338241 0     00:04:03  1391423229  R98338241
# 2014-02-03 10:35:49+00:00 mbta-R98338241 1     00:00:00  1391423749  R98338241
# 2014-02-03 10:37:55+00:00 mbta-R98338241 1     00:02:06  1391423875  R98338241
# 2014-02-03 10:35:34+00:00 mbta-R98338254 1     00:00:00  1391423734  R98338254
# 2014-02-03 10:39:26+00:00 mbta-R98338254 1     00:03:52  1391423966  R98338254

# %%
c = s.stop > 2
print type(c)
# Out:
# <class 'sentenai.flare.Cond'>

# %%
from sentenai import flare

# %%
flare.Cond(s.stop, '>', 2)
# Out:
# (stream "mbta-R983382C1"):stop > 2

# %%
s = flare.Stream('hey', {})
s('hey')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-961a5dfe189f> in <module>()
#       1 s = flare.Stream('hey', {})
# ----> 2 s('hey')
#
# /Users/jltoole/.pyenv/versions/2.7.10/envs/sentenai/lib/python2.7/site-packages/sentenai/flare.pyc in __call__(self, sw)
#     336                 return sw._bind(self)
#     337             except AttributeError as e:
# --> 338                 raise TypeError("A stream should not be called with " + str(type(sw)), e)
#     339
#     340     def __getattr__(self, name):
#
# TypeError: ("A stream should not be called with <type 'str'>", AttributeError("'str' object has no attribute '_bind'",))

# %%
flare.EventPath(['lol', 'bar'])
# Out:
# lol.bar

# %%
import time, datetime

# %%
datetime.timedelta()
